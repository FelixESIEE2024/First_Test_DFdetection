# %%
import os
from pathlib import Path
import shutil
import subprocess

frame = Path(r"C:\Users\conqu\Videos\Detection_Deep_Fake\Repo_1st_test\Implementaiton_1\a10_1_smoke")
destination = Path(r"C:\Users\conqu\Videos\Detection_Deep_Fake\Repo_1st_test\Implementaiton_1\dataset\ai\Geco\Gen_CogVideoX_2b_frame\object_centric_prompts\a10_3\ouais")
repo_dir = Path(r"C:\Users\conqu\Videos\Detection_Deep_Fake\Geco\GeoCalib\GeoCalib")
source_calib = repo_dir / "calib"

os.chdir(repo_dir)
subprocess.run(["python", "intra.py", "--path_frame", str(frame)], check=True)
destination.parent.mkdir(parents=True, exist_ok=True)
if destination.exists():
    shutil.rmtree(destination)
shutil.copytree(source_calib, destination)
# Out:
# WindowsPath('C:/Users/conqu/Videos/Detection_Deep_Fake/Repo_1st_test/Implementaiton_1/dataset/ai/Geco/Gen_CogVideoX_2b_frame/object_centric_prompts/a10_3/ouais')
